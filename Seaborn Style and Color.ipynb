# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('white')
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(x='sex',data=tips)
sns.despine()

# %%
sns.countplot(x='sex',data=tips)
sns.despine(left=True)

# %% [markdown]
# ## Size and Aspect

# %% [markdown]
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=tips)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-5727bab2a1ca> in <module>()
#       1 # Grid Type Plot
# ----> 2 sns.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=tips)
#
# C:\Anaconda\lib\site-packages\seaborn\linearmodels.pyc in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     570         scatter_kws=scatter_kws, line_kws=line_kws,
#     571         )
# --> 572     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     573
#     574     # Add a legend
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.pyc in map_dataframe(self, func, *args, **kwargs)
#     793
#     794         # Finalize the annotations and layout
# --> 795         self._finalize_grid(args[:2])
#     796
#     797         return self
#
# C:\Anaconda\lib\site-packages\seaborn\axisgrid.pyc in _finalize_grid(self, axlabels)
#     818         self.set_axis_labels(*axlabels)
#     819         self.set_titles()
# --> 820         self.fig.tight_layout()
#     821
#     822     def facet_axis(self, row_i, col_j):
#
# C:\Anaconda\lib\site-packages\matplotlib\figure.pyc in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1728                                          rect=rect)
#    1729
# -> 1730         self.subplots_adjust(**kwargs)
#    1731
#    1732
#
# C:\Anaconda\lib\site-packages\matplotlib\figure.pyc in subplots_adjust(self, *args, **kwargs)
#    1584
#    1585         """
# -> 1586         self.subplotpars.update(*args, **kwargs)
#    1587         for ax in self.axes:
#    1588             if not isinstance(ax, SubplotBase):
#
# C:\Anaconda\lib\site-packages\matplotlib\figure.pyc in update(self, left, bottom, right, top, wspace, hspace)
#     228             if self.bottom >= self.top:
#     229                 reset()
# --> 230                 raise ValueError('bottom cannot be >= top')
#     231
#     232     def _update_this(self, s, val):
#
# ValueError: bottom cannot be >= top

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale=4)
sns.countplot(x='sex',data=tips,palette='coolwarm')

# %% [markdown]
# Check out the documentation page for more info on these topics:
# https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html

# %%
sns.puppyplot()
# Out:
# C:\Anaconda\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# <img alt="Bjanka the West Highland White Terrier Pictures 1060156" class="" id="feature_image" src="http://cdn-www.dailypuppy.com/dog-images/bjanka-the-west-highland-white-terrier_61860_2016-09-29_w450.jpg" style="width:450px;"/>

# %% [markdown]
# # Great Job!
